# %%
import pandas as pd

# %%
df = pd.read_excel('acute_oral.xlsx', sheet_name='Data')

# %%
df_selec2 = df[(df['Mixture']=='Chemical') & (df['Species']=='Female')]

# %%
df_selec2['Chemical_Name'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)
